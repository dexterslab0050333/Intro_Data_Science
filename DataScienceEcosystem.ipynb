# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# Introduction
#
# In this notebook, we will explore the tools and ecosystem of data science. We will summarize the most important tools and techniques used in data science and machine learning, as well as some of the popular libraries and frameworks. We will also cover some of the latest trends and developments in the field, such as deep learning and big data analytics. Whether you're new to data science or a seasoned pro, this notebook will provide a helpful overview of the tools and techniques used in the field. Let's get started!

# %% [markdown]
# Objectives:
#
# List popular languages for Data Science
# Identify commonly used libraries in Data Science
# Describe popular development environment open-source tools used in Data Science
# Perform simple arithmetic expressions in Python
# Convert minutes to hours using Python
# These are just some of the key takeaways from this notebook. Depending on the course or tutorial that this notebook is a part of, there may be additional objectives covered as well.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# Python: Python is one of the most popular languages for data science and machine learning. It has a large and active community, which has contributed to the development of numerous libraries and frameworks for data manipulation, analysis, and visualization. Some of the popular libraries in Python for data science include NumPy, Pandas, Matplotlib, and Scikit-Learn.
#
# R: R is another popular language for data science and statistical analysis. It is known for its powerful and comprehensive set of statistical tools, as well as its excellent visualization capabilities. R has a large and active community of users and developers, which has contributed to the development of numerous packages and libraries for data analysis and visualization.
#
# SQL: SQL (Structured Query Language) is a specialized language used for managing and manipulating relational databases. It is commonly used in data science to extract and manipulate data from databases, as well as to perform data cleaning and preprocessing tasks. SQL is a valuable tool for data scientists, as it allows them to work with large datasets efficiently and effectively.

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# NumPy: NumPy is a fundamental library in Python for scientific computing, particularly for arrays and numerical computations. It provides high-performance multidimensional array objects and tools for working with these arrays. NumPy is widely used for numerical analysis and scientific computing, as well as for data cleaning and preprocessing.
#
# Pandas: Pandas is a powerful and easy-to-use library for data manipulation and analysis. It provides data structures for efficiently storing and manipulating large datasets, as well as tools for data cleaning, transformation, and analysis. Pandas is widely used for data analysis and visualization in Python.
#
# Matplotlib: Matplotlib is a popular visualization library in Python for creating high-quality static, animated, and interactive visualizations in Python. It provides a variety of plotting tools and customization options for creating publication-quality figures for data analysis and presentation.
#
# Scikit-Learn: Scikit-Learn is a popular machine learning library in Python for building predictive models from data. It provides a wide range of algorithms for classification, regression, clustering, and dimensionality reduction, as well as tools for model selection and evaluation.

# %% [markdown]
# | Data Science Tools |
# | --- |
# | Jupyter Notebook |
# | RStudio |
# | PyCharm |

# %% [markdown]
# ### <u>Examples of Arithmetic Expressions</u>
#
# Arithmetic expressions are mathematical expressions that involve one or more arithmetic operations, such as addition, subtraction, multiplication, and division. In programming, arithmetic expressions are used to perform mathematical calculations and manipulate numerical data.
#
# Here are some examples of arithmetic expressions:
#
# Addition: 2 + 3 = 5
# Subtraction: 5 - 2 = 3
# Multiplication: 2 * 3 = 6
# Division: 6 / 3 = 2
# Arithmetic expressions can also involve parentheses, which are used to indicate the order of operations. For example:
#
# (2 + 3) * 4 = 20
# In this expression, the addition operation inside the parentheses is performed first, resulting in 5, which is then multiplied by 4 to give the final result of 20.

# %%
# This is a simple arithmetic expression to multiply two integers and add another integer.
3 * 4 + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# Author:
# Dexter Jardin
